# %%
# !nvidia-smi
# Out:
# Wed Mar  6 14:03:25 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# Newest YOLOv9

# %%
# !git clone https://github.com/SkalskiP/yolov9.git
# %cd yolov9
# !pip install -r requirements.txt -q
# Out:
# Cloning into 'yolov9'...
# remote: Enumerating objects: 147, done.
# remote: Counting objects: 100% (77/77), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 147 (delta 45), reused 45 (delta 45), pack-reused 70
# Receiving objects: 100% (147/147), 607.86 KiB | 15.20 MiB/s, done.
# Resolving deltas: 100% (58/58), done.
# /content/yolov9
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 5.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 16.5 MB/s eta 0:00:00

# %%
# !pip install -q roboflow

# %%
import roboflow

from IPython.display import Image

# %%
# !mkdir -p {HOME}/weights

# %%
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-c.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-e.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-c.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-e.pt

# %%
# !ls -la {HOME}/weights
# Out:
# total 402456
# drwxr-xr-x 2 root root      4096 Mar  6 14:43 .
# drwxr-xr-x 1 root root      4096 Mar  6 14:42 ..
# -rw-r--r-- 1 root root  51508261 Feb 18 12:36 gelan-c.pt
# -rw-r--r-- 1 root root 117203713 Feb 18 12:36 gelan-e.pt
# -rw-r--r-- 1 root root 103153312 Feb 18 12:36 yolov9-c.pt
# -rw-r--r-- 1 root root 140217688 Feb 18 12:36 yolov9-e.pt

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="np3XC5TC9BP8aVFRzL9Y")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(8)
dataset = version.download("yolov9")
# Out:
# Requirement already satisfied: roboflow in /usr/local/lib/python3.10/dist-packages (1.1.21)
# Requirement already satisfied: certifi==2023.7.22 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2023.7.22)
# Requirement already satisfied: chardet==4.0.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.0.0)
# Requirement already satisfied: cycler==0.10.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (0.10.0)
# Requirement already satisfied: idna==2.10 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.10)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.4.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from roboflow) (3.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.25.2)
# Requirement already satisfied: opencv-python-headless==4.8.0.74 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.8.0.74)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from roboflow) (9.4.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.8.2)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.31.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.16.0)
# Requirement already satisfied: supervision in /usr/local/lib/python3.10/dist-packages (from roboflow) (0.18.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.0.7)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.66.2)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (6.0.1)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.0.0)
# Requirement already satisfied: python-magic in /usr/local/lib/python3.10/dist-packages (from roboflow) (0.4.27)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (1.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (4.49.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (3.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->roboflow) (3.3.2)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from supervision->roboflow) (0.7.1)
# Requirement already satisfied: scipy<2.0.0,>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from supervision->roboflow) (1.11.4)
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in football-players-detection-8 to yolov9:: 100%|██████████| 57648/57648 [00:01<00:00, 53060.81it/s]
# Extracting Dataset Version Zip to football-players-detection-8 in yolov9:: 100%|██████████| 522/522 [00:00<00:00, 2778.44it/s]

# %%
# %cd {HOME}/yolov9

# !python train.py \
--batch 8 --epochs 10 --img 640 --device 0 --min-items 0 --close-mosaic 15 \
--data {dataset.location}/data.yaml \
--weights {HOME}/weights/gelan-c.pt \
--cfg models/detect/gelan-c.yaml \
--hyp hyp.scratch-high.yaml
# Out:
# /content/yolov9
# 2024-03-06 14:56:03.202668: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-06 14:56:03.202728: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-06 14:56:03.204168: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# train: weights=/content/weights/gelan-c.pt, cfg=models/detect/gelan-c.yaml, data=/content/yolov9/football-players-detection-8/data.yaml, hyp=hyp.scratch-high.yaml, epochs=10, batch_size=8, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, flat_cos_lr=False, fixed_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, min_items=0, close_mosaic=15, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, cls_pw=1.0, dfl=1.5, obj_pw=1.0, iou_t=0.2, anchor_t=5.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.9, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.15, copy_paste=0.3
# ClearML: run 'pip install clearml' to automatically track, visualize and remotely train YOLO 🚀 in ClearML
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLO 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=4
#
#                  from  n    params  module                                  arguments
#   0                -1  1      1856  models.common.Conv                      [3, 64, 3, 2]
#   1                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   2                -1  1    212864  models.common.RepNCSPELAN4              [128, 256, 128, 64, 1]
#   3                -1  1    164352  models.common.ADown                     [256, 256]
#   4                -1  1    847616  models.common.RepNCSPELAN4              [256, 512, 256, 128, 1]
#   5                -1  1    656384  models.common.ADown                     [512, 512]
#   6                -1  1   2857472  models.common.RepNCSPELAN4              [512, 512, 512, 256, 1]
#   7                -1  1    656384  models.common.ADown                     [512, 512]
#   8                -1  1   2857472  models.common.RepNCSPELAN4              [512, 512, 512, 256, 1]
#   9                -1  1    656896  models.common.SPPELAN                   [512, 512, 256]
#  10                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  11           [-1, 6]  1         0  models.common.Concat                    [1]
#  12                -1  1   3119616  models.common.RepNCSPELAN4              [1024, 512, 512, 256, 1]
#  13                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  14           [-1, 4]  1         0  models.common.Concat                    [1]
#  15                -1  1    912640  models.common.RepNCSPELAN4              [1024, 256, 256, 128, 1]
#  16                -1  1    164352  models.common.ADown                     [256, 256]
#  17          [-1, 12]  1         0  models.common.Concat                    [1]
#  18                -1  1   2988544  models.common.RepNCSPELAN4              [768, 512, 512, 256, 1]
#  19                -1  1    656384  models.common.ADown                     [512, 512]
#  20           [-1, 9]  1         0  models.common.Concat                    [1]
#  21                -1  1   3119616  models.common.RepNCSPELAN4              [1024, 512, 512, 256, 1]
#  22      [15, 18, 21]  1   5493724  models.yolo.DDetect                     [4, [256, 512, 512]]
# gelan-c summary: 621 layers, 25440156 parameters, 25440140 gradients, 103.2 GFLOPs
#
# Transferred 931/937 items from /content/weights/gelan-c.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 154 weight(decay=0.0), 161 weight(decay=0.0005), 160 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# train: Scanning /content/yolov9/football-players-detection-8/train/labels... 204 images, 0 backgrounds, 0 corrupt: 100% 204/204 [00:00<00:00, 1491.72it/s]
# train: New cache created: /content/yolov9/football-players-detection-8/train/labels.cache
# val: Scanning /content/yolov9/football-players-detection-8/valid/labels... 38 images, 0 backgrounds, 0 corrupt: 100% 38/38 [00:00<00:00, 954.76it/s]
# val: New cache created: /content/yolov9/football-players-detection-8/valid/labels.cache
# Plotting labels to runs/train/exp2/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/train/exp2
# Starting training for 10 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         0/9      8.15G       1.35      3.014     0.8866        148        640: 100% 26/26 [00:42<00:00,  1.65s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:02<00:00,  1.15it/s]
#                    all         38        905      0.949       0.22      0.226      0.149
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         1/9      9.07G      1.443      1.176     0.8453        297        640: 100% 26/26 [00:26<00:00,  1.03s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  3.66it/s]
#                    all         38        905      0.465       0.28      0.266      0.126
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         2/9      9.07G      1.414      1.323     0.8466        157        640: 100% 26/26 [00:26<00:00,  1.03s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  2.45it/s]
#                    all         38        905      0.774      0.296      0.363      0.143
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         3/9      9.07G      1.641      1.669      0.866        178        640: 100% 26/26 [00:25<00:00,  1.02it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  2.50it/s]
#                    all         38        905       0.64      0.406      0.388      0.192
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         4/9      9.07G      1.814      1.199     0.8748        172        640: 100% 26/26 [00:27<00:00,  1.07s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  3.36it/s]
#                    all         38        905      0.811      0.352      0.411      0.214
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         5/9      9.07G      1.648      1.037     0.8669        213        640: 100% 26/26 [00:27<00:00,  1.06s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  3.74it/s]
#                    all         38        905      0.673      0.447      0.452      0.254
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         6/9      9.98G      1.542     0.9512     0.8506        152        640: 100% 26/26 [00:28<00:00,  1.10s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  3.51it/s]
#                    all         38        905      0.709      0.483      0.503      0.304
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         7/9      10.9G      1.361     0.8118     0.8391        171        640: 100% 26/26 [00:27<00:00,  1.06s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:00<00:00,  3.76it/s]
#                    all         38        905      0.857      0.486      0.558      0.348
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         8/9      10.9G      1.231     0.7358     0.8372        139        640: 100% 26/26 [00:27<00:00,  1.06s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  2.45it/s]
#                    all         38        905      0.853      0.505      0.583      0.369
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         9/9      10.9G      1.198     0.7259     0.8285        106        640: 100% 26/26 [00:26<00:00,  1.02s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:01<00:00,  2.31it/s]
#                    all         38        905      0.868      0.536       0.62      0.406
#
# 10 epochs completed in 0.090 hours.
# Optimizer stripped from runs/train/exp2/weights/last.pt, saved as runs/train/exp2/weights/last_striped.pt, 51.4MB
# Optimizer stripped from runs/train/exp2/weights/best.pt, saved as runs/train/exp2/weights/best_striped.pt, 51.4MB
#
# Validating runs/train/exp2/weights/best.pt...
# Fusing layers...
# gelan-c summary: 467 layers, 25414044 parameters, 0 gradients, 102.5 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:05<00:00,  1.79s/it]
#                    all         38        905      0.869      0.536       0.62      0.405
#                   ball         38         35          1          0     0.0317    0.00713
#             goalkeeper         38         27      0.859      0.667      0.834      0.561
#                 player         38        754      0.896      0.925      0.965      0.647
#                referee         38         89       0.72      0.551      0.649      0.404
# Results saved to runs/train/exp2

# %%
# !ls {HOME}/yolov9/runs/train/exp/
# Out:
# events.out.tfevents.1709736738.06aa7a39eb62.15066.0  labels.jpg        train_batch1.jpg
# hyp.yaml					     opt.yaml	       train_batch2.jpg
# labels_correlogram.jpg				     train_batch0.jpg  weights

# %%
Image(filename=f"{HOME}/yolov9/runs/train/exp2/results.png", width=1000)

# %%
Image(filename=f"{HOME}/yolov9/runs/train/exp2/confusion_matrix.png", width=1000)

# %%
Image(filename=f"{HOME}/yolov9/runs/train/exp2/val_batch0_pred.jpg", width=1000)

# %%
# %cd {HOME}/yolov9

# !python val.py \
--img 640 --batch 8 --conf 0.001 --iou 0.7 --device 0 \
--data {dataset.location}/data.yaml \
--weights {HOME}/yolov9/runs/train/exp2/weights/best.pt
# Out:
# /content/yolov9
# val: data=/content/yolov9/football-players-detection-8/data.yaml, weights=['/content/yolov9/runs/train/exp2/weights/best.pt'], batch_size=8, imgsz=640, conf_thres=0.001, iou_thres=0.7, max_det=300, task=val, device=0, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False, min_items=0
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# gelan-c summary: 467 layers, 25414044 parameters, 0 gradients, 102.5 GFLOPs
# val: Scanning /content/yolov9/football-players-detection-8/valid/labels.cache... 38 images, 0 backgrounds, 0 corrupt: 100% 38/38 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:10<00:00,  2.17s/it]
#                    all         38        905      0.868      0.542      0.622      0.408
#                   ball         38         35          1          0     0.0335    0.00678
#             goalkeeper         38         27      0.862      0.693      0.839      0.569
#                 player         38        754      0.895      0.926      0.965      0.651
#                referee         38         89      0.713      0.551      0.649      0.405
# Speed: 0.1ms pre-process, 58.4ms inference, 44.4ms NMS per image at shape (8, 3, 640, 640)
# Results saved to runs/val/exp

# %%
# !python detect.py \
--img 640 --conf 0.1 --device 0 \
--weights {HOME}/yolov9/runs/train/exp2/weights/best.pt \
--source {dataset.location}/valid/images
# Out:
# detect: weights=['/content/yolov9/runs/train/exp2/weights/best.pt'], source=/content/yolov9/football-players-detection-8/valid/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# gelan-c summary: 467 layers, 25414044 parameters, 0 gradients, 102.5 GFLOPs
# image 1/38 /content/yolov9/football-players-detection-8/valid/images/08fd33_3_1_png.rf.6f25c835bf6d1828dcf584e5969b1f58.jpg: 384x640 25 players, 113.5ms
# image 2/38 /content/yolov9/football-players-detection-8/valid/images/08fd33_3_3_png.rf.128b8280598b9931fdeeed42b5be4c51.jpg: 384x640 22 players, 32.9ms
# image 3/38 /content/yolov9/football-players-detection-8/valid/images/08fd33_9_8_png.rf.cc61e7ba09940f4606e4464dd621fe2f.jpg: 384x640 22 players, 2 referees, 32.9ms
# image 4/38 /content/yolov9/football-players-detection-8/valid/images/121364_7_9_png.rf.bd5ceb93233525ef03fac0eae292f5ed.jpg: 384x640 19 players, 1 referee, 32.8ms
# image 5/38 /content/yolov9/football-players-detection-8/valid/images/121364_9_2_png.rf.400d952c966048709aa5b421889a4dba.jpg: 384x640 21 players, 3 referees, 32.9ms
# image 6/38 /content/yolov9/football-players-detection-8/valid/images/121364_9_3_png.rf.175a041e339a6a4c918ae7f7141461aa.jpg: 384x640 22 players, 5 referees, 32.9ms
# image 7/38 /content/yolov9/football-players-detection-8/valid/images/2e57b9_3_10_png.rf.f85ed097b3476e84600e0a9409959cf4.jpg: 384x640 23 players, 1 referee, 32.9ms
# image 8/38 /content/yolov9/football-players-detection-8/valid/images/2e57b9_3_8_png.rf.6896c68ab1045f7595468d06c0021b79.jpg: 384x640 1 goalkeeper, 21 players, 3 referees, 32.9ms
# image 9/38 /content/yolov9/football-players-detection-8/valid/images/2e57b9_9_1_png.rf.87b260e714b9f6af5288301e51014dc4.jpg: 384x640 2 goalkeepers, 20 players, 3 referees, 32.9ms
# image 10/38 /content/yolov9/football-players-detection-8/valid/images/40cd38_7_7_png.rf.734097f181067cdf149fbd63249a51b2.jpg: 384x640 23 players, 2 referees, 32.8ms
# image 11/38 /content/yolov9/football-players-detection-8/valid/images/42ba34_1_3_png.rf.e18c2b97d91dccbbdfe601c29b4817e3.jpg: 384x640 1 goalkeeper, 23 players, 1 referee, 32.8ms
# image 12/38 /content/yolov9/football-players-detection-8/valid/images/42ba34_1_4_png.rf.0190fbc779b7f4320c25835a5d952de0.jpg: 384x640 1 goalkeeper, 21 players, 3 referees, 32.9ms
# image 13/38 /content/yolov9/football-players-detection-8/valid/images/42ba34_3_2_png.rf.fd1addd604a4c47dea9dba52f7012203.jpg: 384x640 1 goalkeeper, 21 players, 2 referees, 32.9ms
# image 14/38 /content/yolov9/football-players-detection-8/valid/images/42ba34_7_1_png.rf.f8b2cb5fd5d8f39278243a6bfe9279a1.jpg: 384x640 20 players, 1 referee, 32.9ms
# image 15/38 /content/yolov9/football-players-detection-8/valid/images/4b770a_3_1_png.rf.4715dcbc4be0f14fbb5d8450fcff5bf0.jpg: 384x640 21 players, 1 referee, 32.9ms
# image 16/38 /content/yolov9/football-players-detection-8/valid/images/4b770a_3_7_png.rf.0fe6dc6c1fd85518ff5456a914a7571d.jpg: 384x640 22 players, 2 referees, 32.9ms
# image 17/38 /content/yolov9/football-players-detection-8/valid/images/4b770a_5_5_png.rf.32e220f7f4f090859fd2bb2ba0c5d8d1.jpg: 384x640 22 players, 4 referees, 32.7ms
# image 18/38 /content/yolov9/football-players-detection-8/valid/images/538438_1_5_png.rf.927cf8101773ba75712dcee17a35e56b.jpg: 384x640 18 players, 32.9ms
# image 19/38 /content/yolov9/football-players-detection-8/valid/images/538438_9_8_png.rf.f77a8d26e22089ac66e5c925a6d52d70.jpg: 384x640 1 goalkeeper, 23 players, 1 referee, 32.9ms
# image 20/38 /content/yolov9/football-players-detection-8/valid/images/54745b_9_2_png.rf.459f3f85a7dab225b74601302e33d05b.jpg: 384x640 1 goalkeeper, 22 players, 32.7ms
# image 21/38 /content/yolov9/football-players-detection-8/valid/images/54745b_9_4_png.rf.3227ab0fa5e4b28148cbb235e5fa8494.jpg: 384x640 19 players, 1 referee, 32.9ms
# image 22/38 /content/yolov9/football-players-detection-8/valid/images/54745b_9_5_png.rf.277792543ff53b9e63dfe5ebd8b0141e.jpg: 384x640 21 players, 1 referee, 32.9ms
# image 23/38 /content/yolov9/football-players-detection-8/valid/images/54745b_9_6_png.rf.9670b3ae25639828ce68a51f35ab0d95.jpg: 384x640 23 players, 2 referees, 32.9ms
# image 24/38 /content/yolov9/football-players-detection-8/valid/images/573e61_1_10_png.rf.a01a3d439e964eb4342eb9e7d49295e6.jpg: 384x640 18 players, 1 referee, 32.9ms
# image 25/38 /content/yolov9/football-players-detection-8/valid/images/744b27_1_6_png.rf.a47d969e663ab6a912c9ddcb7ac9ada4.jpg: 384x640 23 players, 3 referees, 32.8ms
# image 26/38 /content/yolov9/football-players-detection-8/valid/images/744b27_1_7_png.rf.b2d05a9295c0da84bb0f7107fa0b44f5.jpg: 384x640 22 players, 2 referees, 32.9ms
# image 27/38 /content/yolov9/football-players-detection-8/valid/images/744b27_3_7_png.rf.8611933fe3c87a1f7cdc044eb6076239.jpg: 384x640 1 goalkeeper, 20 players, 2 referees, 32.9ms
# image 28/38 /content/yolov9/football-players-detection-8/valid/images/744b27_7_1_png.rf.f8de7a6218a47e85554c874fb48dbb72.jpg: 384x640 1 goalkeeper, 21 players, 2 referees, 32.9ms
# image 29/38 /content/yolov9/football-players-detection-8/valid/images/744b27_7_5_png.rf.0d0d78b8bd87f5c6e4fff3f07aff5264.jpg: 384x640 1 goalkeeper, 22 players, 2 referees, 34.6ms
# image 30/38 /content/yolov9/football-players-detection-8/valid/images/744b27_7_6_png.rf.1bcd345f6691254eddeea6e9cb8425a4.jpg: 384x640 3 goalkeepers, 19 players, 2 referees, 32.7ms
# image 31/38 /content/yolov9/football-players-detection-8/valid/images/744b27_7_7_png.rf.962e610b06248637fd063e49893216a8.jpg: 384x640 1 goalkeeper, 21 players, 3 referees, 32.5ms
# image 32/38 /content/yolov9/football-players-detection-8/valid/images/744b27_9_8_png.rf.68e5d3f2de2384cd05cdb3f5edbd051b.jpg: 384x640 21 players, 2 referees, 32.7ms
# image 33/38 /content/yolov9/football-players-detection-8/valid/images/798b45_1_1_png.rf.8439a1c181599a0556904a92fd89bd81.jpg: 384x640 22 players, 1 referee, 32.7ms
# image 34/38 /content/yolov9/football-players-detection-8/valid/images/798b45_1_2_png.rf.16fbff81b9da39745fd50739c7f50b60.jpg: 384x640 1 goalkeeper, 18 players, 2 referees, 32.7ms
# image 35/38 /content/yolov9/football-players-detection-8/valid/images/798b45_7_4_png.rf.7e95236908fb69555ee34e25ab14b662.jpg: 384x640 1 goalkeeper, 20 players, 1 referee, 32.7ms
# image 36/38 /content/yolov9/football-players-detection-8/valid/images/798b45_7_5_png.rf.5e0e5e1e6456340e3fb21908d6e028d9.jpg: 384x640 1 goalkeeper, 20 players, 2 referees, 34.7ms
# image 37/38 /content/yolov9/football-players-detection-8/valid/images/798b45_9_8_png.rf.04032c3799e0f6e13589c90ba3c4bdeb.jpg: 384x640 1 goalkeeper, 21 players, 1 referee, 32.4ms
# image 38/38 /content/yolov9/football-players-detection-8/valid/images/a9f16c_8_10_png.rf.9835e230bebd2303d07d0147fe441dfa.jpg: 384x640 1 goalkeeper, 21 players, 2 referees, 32.6ms
# Speed: 0.5ms pre-process, 35.0ms inference, 14.0ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'{HOME}/yolov9/runs/detect/exp/*.jpg')[:3]:
      display(Image(filename=image_path, width=600))
      print("\n")
